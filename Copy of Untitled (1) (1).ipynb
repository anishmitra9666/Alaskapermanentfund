# %%
import pandas as pd

# %%
import numpy as np
# %matplotlib inline

# %%
df1 = pd.read_csv('s133UN01qyLD (2).csv')

# %%
df1
# Out:
#         YEAR  STATEFIP     INCTOT
# 0       1980        23      18919
# 1       1980        23       8203
# 2       1980        23      13680
# 3       1980        23       2802
# 4       1980        23          0
# ...      ...       ...        ...
# 688179  1983        15  999999999
# 688180  1983        15      35002
# 688181  1983        15       8502
# 688182  1983        15          0
# 688183  1983        15  999999999
#
# [688184 rows x 3 columns]

# %%
df2 = pd.read_csv('s165u1u4BUbp (1).csv')

# %%
df2
# Out:
#         YEAR  STATEFIP  RACE
# 0       1980        23   100
# 1       1980        23   100
# 2       1980        23   100
# 3       1980        23   100
# 4       1980        23   100
# ...      ...       ...   ...
# 688179  1983        15   100
# 688180  1983        15   100
# 688181  1983        15   100
# 688182  1983        15   100
# 688183  1983        15   100
#
# [688184 rows x 3 columns]

# %%
grouped1 = df1.groupby('YEAR')
grouped2 = df2.groupby('YEAR')

# %%
'''for name, group in grouped1:
    print(name)
    print(group)
for name, group in grouped2:
    print(name)
    print(group)'''
# Out:
# 'for name, group in grouped1:\n    print(name)\n    print(group)\nfor name, group in grouped2:\n    print(name)\n    print(group)'

# %%
df1
# Out:
#         YEAR  STATEFIP     INCTOT
# 0       1980        23      18919
# 1       1980        23       8203
# 2       1980        23      13680
# 3       1980        23       2802
# 4       1980        23          0
# ...      ...       ...        ...
# 688179  1983        15  999999999
# 688180  1983        15      35002
# 688181  1983        15       8502
# 688182  1983        15          0
# 688183  1983        15  999999999
#
# [688184 rows x 3 columns]

# %%
df1
# Out:
#         YEAR  STATEFIP     INCTOT
# 0       1980        23      18919
# 1       1980        23       8203
# 2       1980        23      13680
# 3       1980        23       2802
# 4       1980        23          0
# ...      ...       ...        ...
# 688179  1983        15  999999999
# 688180  1983        15      35002
# 688181  1983        15       8502
# 688182  1983        15          0
# 688183  1983        15  999999999
#
# [688184 rows x 3 columns]

# %%
years = [1980, 1981, 1982, 1983]
yearnames = [df1980, df1981, df1982, df1983]
for x in years:
    for y in yearnames:
        y = df1[df1['YEAR'] == x]

# %%
states= [ "AK - Alaska", 
                "AL - Alabama", 
                "AR - Arkansas", 
                "AS - American Samoa", 
                "AZ - Arizona", 
                "CA - California", 
                "CO - Colorado", 
                "CT - Connecticut", 
                "DC - District of Columbia", 
                "DE - Delaware", 
                "FL - Florida", 
                "GA - Georgia", 
                "GU - Guam", 
                "HI - Hawaii", 
                "IA - Iowa", 
                "ID - Idaho", 
                "IL - Illinois", 
                "IN - Indiana", 
                "KS - Kansas", 
                "KY - Kentucky", 
                "LA - Louisiana", 
                "MA - Massachusetts", 
                "MD - Maryland", 
                "ME - Maine", 
                "MI - Michigan", 
                "MN - Minnesota", 
                "MO - Missouri", 
                "MS - Mississippi", 
                "MT - Montana", 
                "NC - North Carolina", 
                "ND - North Dakota", 
                "NE - Nebraska", 
                "NH - New Hampshire", 
                "NJ - New Jersey", 
                "NM - New Mexico", 
                "NV - Nevada", 
                "NY - New York", 
                "OH - Ohio", 
                "OK - Oklahoma", 
                "OR - Oregon", 
                "PA - Pennsylvania", 
                "PR - Puerto Rico", 
                "RI - Rhode Island", 
                "SC - South Carolina", 
                "SD - South Dakota", 
                "TN - Tennessee", 
                "TX - Texas", 
                "UT - Utah", 
                "VA - Virginia", 
                "VI - Virgin Islands", 
                "VT - Vermont", 
                "WA - Washington", 
                "WI - Wisconsin", "WV - West Virginia", "WY - Wyoming"]
dataframes= ["df1980", "df1981", "df1982", "df1983"]
for x in states:
    for y in dataframes:
        print(y+x)
# Out:
# df1980AK - Alaska
# df1981AK - Alaska
# df1982AK - Alaska
# df1983AK - Alaska
# df1980AL - Alabama
# df1981AL - Alabama
# df1982AL - Alabama
# df1983AL - Alabama
# df1980AR - Arkansas
# df1981AR - Arkansas
# df1982AR - Arkansas
# df1983AR - Arkansas
# df1980AS - American Samoa
# df1981AS - American Samoa
# df1982AS - American Samoa
# df1983AS - American Samoa
# df1980AZ - Arizona
# df1981AZ - Arizona
# df1982AZ - Arizona
# df1983AZ - Arizona
# df1980CA - California
# df1981CA - California
# df1982CA - California
# df1983CA - California
# df1980CO - Colorado
# df1981CO - Colorado
# df1982CO - Colorado
# df1983CO - Colorado
# df1980CT - Connecticut
# df1981CT - Connecticut
# df1982CT - Connecticut
# df1983CT - Connecticut
# df1980DC - District of Columbia
# df1981DC - District of Columbia
# df1982DC - District of Columbia
# df1983DC - District of Columbia
# df1980DE - Delaware
# df1981DE - Delaware
# df1982DE - Delaware
# df1983DE - Delaware
# df1980FL - Florida
# df1981FL - Florida
# ...

# %%
stateandyearnames = [df1980AK - Alaska,
df1981AK - Alaska,
df1982AK - Alaska,
df1983AK - Alaska,
df1980AL - Alabama,
df1981AL - Alabama,
df1982AL - Alabama,
df1983AL - Alabama,
df1980AR - Arkansas,
df1981AR - Arkansas,
df1982AR - Arkansas,
df1983AR - Arkansas,
df1980AS - American Samoa,
df1981AS - American Samoa,
df1982AS - American Samoa,
df1983AS - American Samoa,
df1980AZ - Arizona,
df1981AZ - Arizona,
df1982AZ - Arizona,
df1983AZ - Arizona,
df1980CA - California,
df1981CA - California,
df1982CA - California,
df1983CA - California,
df1980CO - Colorado,
df1981CO - Colorado,
df1982CO - Colorado,
df1983CO - Colorado,
df1980CT - Connecticut,
df1981CT - Connecticut,
df1982CT - Connecticut,
df1983CT - Connecticut,
df1980DC - District of Columbia,
df1981DC - District of Columbia,
df1982DC - District of Columbia,
df1983DC - District of Columbia,
df1980DE - Delaware,
df1981DE - Delaware,
df1982DE - Delaware,
df1983DE - Delaware,
df1980FL - Florida,
df1981FL - Florida,
df1982FL - Florida,
df1983FL - Florida,
df1980GA - Georgia,
df1981GA - Georgia,
df1982GA - Georgia,
df1983GA - Georgia,
df1980GU - Guam,
df1981GU - Guam,
df1982GU - Guam,
df1983GU - Guam,
df1980HI - Hawaii,
df1981HI - Hawaii,
df1982HI - Hawaii,
df1983HI - Hawaii,
df1980IA - Iowa,
df1981IA - Iowa,
df1982IA - Iowa,
df1983IA - Iowa,
df1980ID - Idaho,
df1981ID - Idaho,
df1982ID - Idaho,
df1983ID - Idaho,
df1980IL - Illinois,
df1981IL - Illinois,
df1982IL - Illinois,
df1983IL - Illinois,
df1980IN - Indiana,
df1981IN - Indiana,
df1982IN - Indiana,
df1983IN - Indiana,
df1980KS - Kansas,
df1981KS - Kansas,
df1982KS - Kansas,
df1983KS - Kansas,
df1980KY - Kentucky,
df1981KY - Kentucky,
df1982KY - Kentucky,
df1983KY - Kentucky,
df1980LA - Louisiana,
df1981LA - Louisiana,
df1982LA - Louisiana,
df1983LA - Louisiana,
df1980MA - Massachusetts,
df1981MA - Massachusetts,
